# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re
import math
from scipy import interpolate
plt.rc('font',family='Times New Roman')

# %%
L=420e-6
H=80e-6
Pe = 0.01
DO2 = 7.63596e-6
H = 80e-6
w=20e-6
U_0 = Pe*DO2/w
umax=1.5*U_0
Tref=773
rhof=4.4908
Mwf=0.02888
x_O2=0.22

# %% [markdown]
# # Read COMSOL Data

# %% [markdown]
# ## Read Centerline x from COMSOL

# %%
x_centerline_file_comsol=f"./output-x-centerline_timestep1e-5.txt"
with open(x_centerline_file_comsol,"r") as fp:
    lines=fp.readlines()
    header=lines[8]
header=re.split(r" +(?![t@(])",header)
header.pop(0)
header[-1]=header[-1].strip()
df_comsol_x_centerline = pd.read_csv(x_centerline_file_comsol, comment='%', sep='\\s+', header=None,names=header)
df_comsol_x_centerline.sort_values(by="x",inplace=True)
df_comsol_x_centerline.reset_index(drop=True,inplace=True)
df_comsol_x_centerline.fillna(0,inplace=True)
df_comsol_x_centerline.head()
# Out:
#               x        y  u (m/s) @ t=0.002  T (K) @ t=0.002  \
# 0  0.000000e+00  0.00004           0.005727       773.000000
# 1  1.198662e-10  0.00004           0.005727       773.000012
# 2  2.930714e-06  0.00004           0.005707       773.303560
# 3  5.856840e-06  0.00004           0.005719       773.607293
# 4  5.858781e-06  0.00004           0.005719       773.607494
#
#    c_O2 (mol/m^3) @ t=0.002  c_CO2 (mol/m^3) @ t=0.002  u (m/s) @ t=0.004  \
# 0                 34.209695                   0.000000           0.005727
# 1                 34.209677                   0.000003           0.005727
# 2                 33.757499                   0.070051           0.005707
# 3                 33.305173                   0.140219           0.005719
# 4                 33.304872                   0.140265           0.005719
#
#    T (K) @ t=0.004  c_O2 (mol/m^3) @ t=0.004  c_CO2 (mol/m^3) @ t=0.004  ...  \
# 0       773.000000                 34.209695                   0.000000  ...
# 1       773.000045                 34.209677                   0.000008  ...
# 2       774.108827                 33.760722                   0.198339  ...
# 3       775.217908                 33.311505                   0.396909  ...
# 4       775.218644                 33.311207                   0.397041  ...
#
#    c_O2 (mol/m^3) @ t=0.04  c_CO2 (mol/m^3) @ t=0.04  u (m/s) @ t=0.05  \
# 0                34.209695                  0.000000          0.005727
# 1                34.209658                  0.000040          0.005727
# 2                33.308619                  0.977337          0.005707
# 3                32.407106                  1.955345          0.005719
# 4                32.406508                  1.955994          0.005719
#
#    T (K) @ t=0.05  c_O2 (mol/m^3) @ t=0.05  c_CO2 (mol/m^3) @ t=0.05  \
# 0      773.000000                34.209695                  0.000000
# 1      773.001078                34.209658                  0.000040
# 2      799.356248                33.308562                  0.982596
# 3      825.708247                32.406992                  1.965866
# 4      825.725732                32.406394                  1.966518
#
#    u (m/s) @ t=0.06  T (K) @ t=0.06  c_O2 (mol/m^3) @ t=0.06  \
# 0          0.005727      773.000000                34.209695
# 1          0.005727      773.001176                34.209658
# 2          0.005707      801.757119                33.308534
# 3          0.005719      830.509510                32.406936
# 4          0.005719      830.528588                32.406338
#
#    c_CO2 (mol/m^3) @ t=0.06
# 0                  0.000000
# 1                  0.000040
# 2                  0.984568
# 3                  1.969811
# 4                  1.970465
#
# [5 rows x 38 columns]

# %% [markdown]
# # Validate

# %% [markdown]
# ## Function Dev

# %%
def validate(df_comsol=df_comsol_x_centerline,time=0.002,file="x-centerline_T_O2_CO2.csv",axis='x',obj='T',refLength=L,refValue=Tref):
    path=f"../postProcessing/singleGraph/{str(time)}/{file}"
    df_dbs=pd.read_csv(path)
    df_norm_dbs=pd.DataFrame(columns=["NormalizedLength","NormalizedValue"])
    if obj=="T":
        df_norm_dbs["NormalizedLength"]=df_dbs[axis]/refLength
        df_norm_dbs["NormalizedValue"]=df_dbs[obj]/refValue
    else:
        df_norm_dbs["NormalizedLength"]=df_dbs[axis]/refLength
        df_norm_dbs["NormalizedValue"]=df_dbs[obj]
    df_norm_dbs.head()
    if obj=='T':
        comsol_label=f"T (K) @ t={time}"
    elif obj=="O2" or obj=="CO2":
        comsol_label=f"c_{obj} (mol/m^3) @ t={time}"
    df_norm_comsol=pd.DataFrame(columns=["NormalizedLength","NormalizedValue"])
    df_norm_comsol["NormalizedLength"]=df_comsol[axis]/refLength
    df_norm_comsol["NormalizedValue"]=df_comsol[comsol_label]/refValue

    interp_f=interpolate.interp1d(df_norm_comsol["NormalizedLength"],df_norm_comsol["NormalizedValue"],kind="linear")
    df_norm_comsol_interpolated=interp_f(df_norm_dbs["NormalizedLength"])

    relative_error=0.0
    num=0
    if obj=="T":
        reduce=1
    else:
        reduce=0
    maxerror=-1e6
    for i in df_norm_dbs.index:
        benmark=df_norm_comsol_interpolated[i]
        dbs=df_norm_dbs["NormalizedValue"][i]
        if(benmark>1e-16):
            num+=1
            error=(dbs-benmark)/(benmark-reduce)  #relative to the temperature increase
            if maxerror<abs(error):
                maxerror=abs(error)
                adbs=dbs
                abenchmark=benmark
                ai=i
            relative_error+=pow(error,2)
    print(f"Max Relative Error: {maxerror}")
    print(f"Max Relative Error detailed Info: location: {ai/df_norm_dbs.index.shape[0]} comsol value: {abenchmark}, dbs value: {adbs},")
    relative_error=math.sqrt(relative_error/num) # Root-mean square residual
    print(f"non-zero value num: {num}")
    print(f"RMSR Relative Error: {relative_error*100}%")

    df_norm_dbs_sampling=df_norm_dbs[df_norm_dbs.index%10==0]
    fig, ax = plt.subplots()
    ax.plot(df_norm_comsol["NormalizedLength"],df_norm_comsol["NormalizedValue"],label="COMSOL")
    ax.scatter(df_norm_dbs_sampling["NormalizedLength"],df_norm_dbs_sampling["NormalizedValue"],color="",marker="o",s=15,edgecolors="r",label="DBS")
    ax.set_xlabel(f"Dimensionless {axis}")
    ax.set_ylabel(f"Dimensionless {obj}")
    ax.set_title(f"{obj} centerline: DBS vs FEM")
    # ax.text(0.7,0.2,f" relative error: {:.2f}%".format(relative_error_ux*100))
    ax.legend(loc="upper right")

# %% [markdown]
# ## Validate Temperature

# %%
validate(df_comsol=df_comsol_x_centerline,time=0.002,file="x-centerline_T_O2_CO2.csv",axis='x',obj='T',refLength=L,refValue=Tref)
# Out:
# Max Relative Error: 0.7378044581642043
# Max Relative Error detailed Info: location: 0.0 comsol value: 1.0000223326805509, dbs value: 1.000038809831824,
# non-zero value num: 1261
# RMSR Relative Error: 2.3985725165408223%

# %%
validate(df_comsol=df_comsol_x_centerline,time=0.004,file="x-centerline_T_O2_CO2.csv",axis='x',obj='T',refLength=L,refValue=Tref)
# Out:
# Max Relative Error: 0.7285684922910902
# Max Relative Error detailed Info: location: 0.0 comsol value: 1.000081575625297, dbs value: 1.0001410090556273,
# non-zero value num: 1261
# RMSR Relative Error: 2.3361685538329513%

# %%
validate(df_comsol=df_comsol_x_centerline,time=0.006,file="x-centerline_T_O2_CO2.csv",axis='x',obj='T',refLength=L,refValue=Tref)
# Out:
# Max Relative Error: 0.7210329285532956
# Max Relative Error detailed Info: location: 0.0 comsol value: 1.0002119729454872, dbs value: 1.000364812419146,
# non-zero value num: 1261
# RMSR Relative Error: 2.3513117501528074%

# %% [markdown]
# ## Validate O2

# %%
validate(df_comsol=df_comsol_x_centerline,time=0.002,file="x-centerline_T_O2_CO2.csv",axis='x',obj='O2',refLength=L,refValue=rhof/Mwf)
# Out:
# Max Relative Error: 11.820501759614894
# Max Relative Error detailed Info: location: 0.3346550356859635 comsol value: 0.0063555390832415876, dbs value: 0.0814812,
# non-zero value num: 1032
# RMSR Relative Error: 50.67856260953214%

# %%
validate(df_comsol=df_comsol_x_centerline,time=0.004,file="x-centerline_T_O2_CO2.csv",axis='x',obj='O2',refLength=L,refValue=rhof/Mwf)
# Out:
# Max Relative Error: 12.241768767654774
# Max Relative Error detailed Info: location: 0.3346550356859635 comsol value: 0.0060732823092668475, dbs value: 0.080421,
# non-zero value num: 1032
# RMSR Relative Error: 52.46334689940851%

# %%
validate(df_comsol=df_comsol_x_centerline,time=0.006,file="x-centerline_T_O2_CO2.csv",axis='x',obj='O2',refLength=L,refValue=rhof/Mwf)
# Out:
# Max Relative Error: 13.256118373863904
# Max Relative Error detailed Info: location: 0.3346550356859635 comsol value: 0.002909894468613089, dbs value: 0.0414838,
# non-zero value num: 1032
# RMSR Relative Error: 55.76689082852073%

# %% [markdown]
# ## Validate CO2

# %%
validate(df_comsol=df_comsol_x_centerline,time=0.002,file="x-centerline_T_O2_CO2.csv",axis='x',obj='CO2',refLength=L,refValue=rhof/Mwf)
# Out:
# Max Relative Error: 11.228672600759552
# Max Relative Error detailed Info: location: 0.3346550356859635 comsol value: 0.0019076395911156417, dbs value: 0.023327900000000002,
# non-zero value num: 1032
# RMSR Relative Error: 48.2900989797809%

# %%
validate(df_comsol=df_comsol_x_centerline,time=0.004,file="x-centerline_T_O2_CO2.csv",axis='x',obj='CO2',refLength=L,refValue=rhof/Mwf)
# Out:
# Max Relative Error: 11.538666494381049
# Max Relative Error detailed Info: location: 0.3346550356859635 comsol value: 0.004818582584286406, dbs value: 0.0604186,
# non-zero value num: 1032
# RMSR Relative Error: 49.68039494288083%

# %%
validate(df_comsol=df_comsol_x_centerline,time=0.006,file="x-centerline_T_O2_CO2.csv",axis='x',obj='CO2',refLength=L,refValue=rhof/Mwf)
# Out:
# Max Relative Error: 11.588051878707038
# Max Relative Error detailed Info: location: 0.3346550356859635 comsol value: 0.009550882150665949, dbs value: 0.120227,
# non-zero value num: 1032
# RMSR Relative Error: 49.97597759172389%
