# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_dbs=pd.read_csv("./Ux_centerline_1.5s(DBS).csv")
Ux0_mid_inlet=0.45
df_dbs["U_X_norm"]=df_dbs["U_X"]/Ux0_mid_inlet
df_dbs.head()
# Out:
#    arc_length       U_X  U_X_norm
# 0    0.000000  0.449989  0.999976
# 1    0.000245  0.449989  0.999976
# 2    0.000490  0.449989  0.999976
# 3    0.000735  0.449989  0.999976
# 4    0.000980  0.449989  0.999976

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101 entries, 0 to 1000
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   arc_length  101 non-null    float64
#  1   U_X         101 non-null    float64
#  2   U_X_norm    101 non-null    float64
# dtypes: float64(3)
# memory usage: 3.2 KB

# %%
3%2
# Out:
# 1

# %%
df_dbs_sampling.head()
# Out:
#    arc_length       U_X  U_X_norm
# 0         0.0  0.449989  0.999976

# %%
df_dbs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   arc_length  1001 non-null   float64
#  1   U_X         1001 non-null   float64
# dtypes: float64(2)
# memory usage: 15.8 KB

# %%
plt.plot(df_dbs["arc_length"],df_dbs["U_X_norm"])

# %%
df_lb=pd.read_csv("./Ux_centerline(LB).dat")
Ux0_mid_inlet_lb=0.15
df_lb["U_X_norm"]=df_lb["U_X"]/Ux0_mid_inlet_lb
df_lb["arc_length"]=df_lb["arc_length"]/10000
df_lb.head()
# Out:
#    arc_length       U_X  U_X_norm
# 0      0.0000  0.149985  0.999900
# 1      0.0001  0.149984  0.999893
# 2      0.0002  0.149984  0.999894
# 3      0.0003  0.149984  0.999895
# 4      0.0004  0.149984  0.999895

# %%
plt.plot(df_lb["arc_length"],df_lb["U_X_norm"])

# %%
df_dbs_sampling=df_dbs[df_dbs.index%10==0]
df_dbs_sampling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101 entries, 0 to 1000
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   arc_length  101 non-null    float64
#  1   U_X         101 non-null    float64
#  2   U_X_norm    101 non-null    float64
# dtypes: float64(3)
# memory usage: 3.2 KB

# %%
plt.rc('font',family='Times New Roman')

# %%
fig, ax = plt.subplots()
ax.plot(df_lb["arc_length"],df_lb["U_X_norm"],label="LB")
ax.scatter(df_dbs_sampling["arc_length"],df_dbs_sampling["U_X_norm"],color="r",marker="o",s=3,label="DBS")
ax.set_xlabel("X")
ax.set_ylabel("U_X")
ax.set_title("Ux centerline: DBS vs LB")
ax.legend()
